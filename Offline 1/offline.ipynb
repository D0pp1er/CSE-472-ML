# %% [markdown]
# # 1. Understanding the dataset

# %% [markdown]
# 1.1 Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# 1.2 Load the dataset

# %%
file_path = "WA_Fn-UseC_-HR-Employee-Attrition.csv"
df = pd.read_csv(file_path)

# %% [markdown]
# 1.3 Show the number of attributes (columns) and number of records (rows)

# %%
num_rows, num_columns = df.shape
print(f"Number of rows: {num_rows}")
print(f"Number of columns: {num_columns}")
# Out:
# Number of rows: 1470
# Number of columns: 35

# %% [markdown]
# 1.4 Show the statistics of the dataset

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
df.head(5)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %% [markdown]
# 1.5 Count the number of missing values in the dataset

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
#         Age  Attrition  BusinessTravel  DailyRate  Department  \
# 0     False      False           False      False       False
# 1     False      False           False      False       False
# 2     False      False           False      False       False
# 3     False      False           False      False       False
# 4     False      False           False      False       False
# ...     ...        ...             ...        ...         ...
# 1465  False      False           False      False       False
# 1466  False      False           False      False       False
# 1467  False      False           False      False       False
# 1468  False      False           False      False       False
# 1469  False      False           False      False       False
#
#       DistanceFromHome  Education  EducationField  EmployeeCount  \
# 0                False      False           False          False
# 1                False      False           False          False
# ...

# %% [markdown]
# 1.6 Count the number of duplicate values in the dataset

# %%
dupliate_values=df.duplicated().sum()   
print(f"Number of duplicate rows: {dupliate_values}")
# Out:
# Number of duplicate rows: 0

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# 2.1 Replace missing values with the column-wise mean

# %%
df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Age, Attrition, BusinessTravel, DailyRate, Department, DistanceFromHome, Education, EducationField, EmployeeCount, EmployeeNumber, EnvironmentSatisfaction, Gender, HourlyRate, JobInvolvement, JobLevel, JobRole, JobSatisfaction, MaritalStatus, MonthlyIncome, MonthlyRate, NumCompaniesWorked, Over18, OverTime, PercentSalaryHike, PerformanceRating, RelationshipSatisfaction, StandardHours, StockOptionLevel, TotalWorkingYears, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsInCurrentRole, YearsSinceLastPromotion, YearsWithCurrManager]
# Index: []
#
# [0 rows x 35 columns]

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Age, Attrition, BusinessTravel, DailyRate, Department, DistanceFromHome, Education, EducationField, EmployeeCount, EmployeeNumber, EnvironmentSatisfaction, Gender, HourlyRate, JobInvolvement, JobLevel, JobRole, JobSatisfaction, MaritalStatus, MonthlyIncome, MonthlyRate, NumCompaniesWorked, Over18, OverTime, PercentSalaryHike, PerformanceRating, RelationshipSatisfaction, StandardHours, StockOptionLevel, TotalWorkingYears, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsInCurrentRole, YearsSinceLastPromotion, YearsWithCurrManager]
# Index: []
#
# [0 rows x 35 columns]

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
object_dtypes = df.select_dtypes(include='object').columns
print(f"Object columns: {object_dtypes}")
# Out:
# Object columns: Index(['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'Gender',
#        'JobRole', 'MaritalStatus', 'Over18', 'OverTime'],
#       dtype='object')

# %%
for column in object_dtypes:
    df[column] = df[column].astype('category')

df.dtypes
# Out:
# Age                            int64
# Attrition                   category
# BusinessTravel              category
# DailyRate                      int64
# Department                  category
# DistanceFromHome               int64
# Education                      int64
# EducationField              category
# EmployeeCount                  int64
# EmployeeNumber                 int64
# EnvironmentSatisfaction        int64
# Gender                      category
# HourlyRate                     int64
# JobInvolvement                 int64
# JobLevel                       int64
# JobRole                     category
# JobSatisfaction                int64
# MaritalStatus               category
# MonthlyIncome                  int64
# MonthlyRate                    int64
# NumCompaniesWorked             int64
# Over18                      category
# OverTime                    category
# PercentSalaryHike              int64
# PerformanceRating              int64
# ...

# %%
numerical_cols = df.select_dtypes(include=['number']).columns
categorical_cols = df.select_dtypes(include=['category']).columns

df[numerical_cols] = df[numerical_cols].fillna(df[numerical_cols].mean())

df[categorical_cols] = df[categorical_cols].apply(lambda x: x.fillna(x.mode()[0]))

df.isnull().sum().sum() 
df.isnull().sum()
df.dtypes
# Out:
# Age                            int64
# Attrition                   category
# BusinessTravel              category
# DailyRate                      int64
# Department                  category
# DistanceFromHome               int64
# Education                      int64
# EducationField              category
# EmployeeCount                  int64
# EmployeeNumber                 int64
# EnvironmentSatisfaction        int64
# Gender                      category
# HourlyRate                     int64
# JobInvolvement                 int64
# JobLevel                       int64
# JobRole                     category
# JobSatisfaction                int64
# MaritalStatus               category
# MonthlyIncome                  int64
# MonthlyRate                    int64
# NumCompaniesWorked             int64
# Over18                      category
# OverTime                    category
# PercentSalaryHike              int64
# PerformanceRating              int64
# ...

# %%
df.drop_duplicates(inplace=True)
df.dtypes
# Out:
# Age                            int64
# Attrition                   category
# BusinessTravel              category
# DailyRate                      int64
# Department                  category
# DistanceFromHome               int64
# Education                      int64
# EducationField              category
# EmployeeCount                  int64
# EmployeeNumber                 int64
# EnvironmentSatisfaction        int64
# Gender                      category
# HourlyRate                     int64
# JobInvolvement                 int64
# JobLevel                       int64
# JobRole                     category
# JobSatisfaction                int64
# MaritalStatus               category
# MonthlyIncome                  int64
# MonthlyRate                    int64
# NumCompaniesWorked             int64
# Over18                      category
# OverTime                    category
# PercentSalaryHike              int64
# PerformanceRating              int64
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
features = df.drop(columns=['Attrition'])
target = df['Attrition']

# %%
from sklearn.preprocessing import LabelEncoder

target
label_encoder = LabelEncoder()
target_encoded = label_encoder.fit_transform(target)

for col in features.select_dtypes(include=['category']).columns:
    if features[col].nunique() == 2:
        features[col] = label_encoder.fit_transform(features[col])



features = pd.get_dummies(features)

# %%
target_encoded
# Out:
# array([1, 0, 1, ..., 0, 0, 0])

# %%
# Count the data types in the features DataFrame
dtype_counts = features.dtypes.value_counts()
print("Data type counts in features:")
print(dtype_counts)

# Print the columns with only 1 unique value
for col in features.columns:
    unique_values = features[col].unique()
    if len(unique_values) == 1:
        print(f"Column: {col}, Unique Values: {unique_values}")
count = 0
# Print columns with more than 2 unique values or exactly 2 unique values but not {0, 1}
for col in features.columns:
    unique_values = features[col].unique()
    if len(unique_values) > 2 or (len(unique_values) == 2 and set(unique_values) != {0, 1}):
        # print(f"Column: {col}, Unique Values: {unique_values}")
        count+=1

print(f"Columns with more than 2 unique values or exactly 2 unique values but not {0, 1}: {count}")
# Out:
# Data type counts in features:
# int64    28
# uint8    25
# dtype: int64
# Column: EmployeeCount, Unique Values: [1]
# Column: StandardHours, Unique Values: [80]
# Column: Over18_Y, Unique Values: [1]
# Columns with more than 2 unique values or exactly 2 unique values but not (0, 1): 24

# %%
def scale_features(features, scaling_method):
    from sklearn.preprocessing import StandardScaler, MinMaxScaler
    if scaling_method == 'standard':
        scaler = StandardScaler()
    elif scaling_method == 'minmax':
        scaler = MinMaxScaler()

    for col in features.columns:
        unique_values = features[col].unique()
        if len(unique_values) > 2 or (len(unique_values) == 2 and set(unique_values) != {0, 1}):
            features[col] = scaler.fit_transform(features[[col]])
    
    # columns_to_scale = features[cols_with_more_than_2_unique_values].columns
    # features[cols_with_more_than_2_unique_values] = scaler.fit_transform(features[cols_with_more_than_2_unique_values])

# %%
scale_features(features, 'standard')
# scale_features(features, 'minmax')

# %%
target_encoded
# Out:
# array([1, 0, 1, ..., 0, 0, 0])

# %%
# import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'features' is your DataFrame with numeric features and 'target' is your target column
# Calculate the correlation of each feature with the target column
features_df = pd.DataFrame(features, columns=features.columns)
target_df = pd.DataFrame(target_encoded,columns=['Attrition'])
target_series = target_df['Attrition']  
correlation = features_df.corrwith(target_series)
# Display the correlation values
print("Correlation of each feature with the target column:")
print(correlation)
# Out:
# Correlation of each feature with the target column:
# Age                                 -0.159205
# DailyRate                           -0.056652
# DistanceFromHome                     0.077924
# Education                           -0.031373
# EmployeeCount                             NaN
# EmployeeNumber                      -0.010577
# EnvironmentSatisfaction             -0.103369
# Gender                               0.029453
# HourlyRate                          -0.006846
# JobInvolvement                      -0.130016
# JobLevel                            -0.169105
# JobSatisfaction                     -0.103481
# MonthlyIncome                       -0.159840
# MonthlyRate                          0.015170
# NumCompaniesWorked                   0.043494
# OverTime                             0.246118
# PercentSalaryHike                   -0.013478
# PerformanceRating                    0.002889
# RelationshipSatisfaction            -0.045872
# ...

# %%
# Create a correlation matrix
correlation_matrix = features_df.corr()
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# %%
# Select the top 20 features with the highest correlation with the target variable
top_20_features = correlation.abs().sort_values(ascending=False).head(20).index
print("Top 20 features with the highest correlation with the target variable:")
print(top_20_features)
final_features = features_df[top_20_features]
# Out:
# Top 20 features with the highest correlation with the target variable:
# Index(['OverTime', 'MaritalStatus_Single', 'TotalWorkingYears', 'JobLevel',
#        'YearsInCurrentRole', 'MonthlyIncome', 'Age',
#        'JobRole_Sales Representative', 'YearsWithCurrManager',
#        'StockOptionLevel', 'YearsAtCompany', 'JobInvolvement',
#        'BusinessTravel_Travel_Frequently', 'JobSatisfaction',
#        'EnvironmentSatisfaction', 'JobRole_Laboratory Technician',
#        'MaritalStatus_Married', 'JobRole_Research Director',
#        'MaritalStatus_Divorced', 'Department_Research & Development'],
#       dtype='object')

# %%
correlation_matrix = final_features.corr()

# Create a heatmap of the correlation matrix
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap of Top 20 Features')
plt.show()
plt.savefig('correlation_heatmap.png')

# %%
# Create 1D scatter plots for the top 20 features 
class_0 = features_df.loc[target_df['Attrition'] == 0]
class_1 = features_df.loc[target_df['Attrition'] == 1]
import numpy as np
for feature in top_20_features:
    # plt.figure(figsize=(8, 6))
    # plt.scatter(features[feature][class_0], [0] * len(features[feature][class_0]), color='b', label='0', alpha=0.5)
    # plt.scatter(features[feature][class_1], [0] * len(features[feature][class_1]), color='r', label='1', alpha=0.5)
    plt.plot(class_0[feature],np.zeros_like(class_0[feature]), 'o', label='0')
    plt.plot(class_1[feature],np.zeros_like(class_1[feature]), 'o', label='1')


    plt.title(f"1D Scatter Plot of Feature: {feature}")
    plt.legend(['0', '1'])
    plt.savefig(f"Figures/{feature}_scatter_plot.png")
    plt.close()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
X_train, X_test, y_train, y_test = train_test_split(final_features, target_encoded, test_size=0.2, random_state=42)
clf = LogisticRegression()
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy*100:.2f}%")
# Out:
# Accuracy: 87.07%
